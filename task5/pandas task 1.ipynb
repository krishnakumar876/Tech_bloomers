# %%
import pandas as pd
import numpy as np

# %%
a ={
    'Fruits':[1,2,3,4],
    'vegetables':["onion","tomato","birinjal","carrot"],
    'c':[1,2,3,4]
}
df=pd.DataFrame(a)
df
# Out:
#    Fruits vegetables  c
# 0       1      onion  1
# 1       2     tomato  2
# 2       3   birinjal  3
# 3       4     carrot  4

# %%
d = {
    'A': [1,2, np.nan,4],
    'B':[5, np.nan, np.nan,4],
    'C':[1,2,3,4]
}
df=pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 3  4.0  4.0  4

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df.describe()
# Out:
#               A         B         C
# count  3.000000  2.000000  4.000000
# mean   2.333333  4.500000  2.500000
# std    1.527525  0.707107  1.290994
# min    1.000000  4.000000  1.000000
# 25%    1.500000  4.250000  1.750000
# 50%    2.000000  4.500000  2.500000
# 75%    3.000000  4.750000  3.250000
# max    4.000000  5.000000  4.000000

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df.fillna(value="0")
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0    0  2
# 2    0    0  3
# 3  4.0  4.0  4

# %%
df.fillna(value="1")
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0    1  2
# 2    1    1  3
# 3  4.0  4.0  4

# %%
pd.DataFrame()
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3
# 3  4.0  4.0  4

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# Name: A, dtype: float64

# %%
df['A'].fillna(value = df['A'].mean(), inplace = True)
# Out:
# /tmp/ipython-input-42-2171742998.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value = df['A'].mean(), inplace = True)

# %%
df
# Out:
#           A    B  C
# 0  1.000000  5.0  1
# 1  2.000000  NaN  2
# 2  2.333333  NaN  3
# 3  4.000000  4.0  4

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
pd.DataFrame(data)
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df
# Out:
#           A    B  C
# 0  1.000000  5.0  1
# 1  2.000000  NaN  2
# 2  2.333333  NaN  3
# 3  4.000000  4.0  4

# %%
df.mean(numeric_only=True)
# Out:
# A    2.333333
# B    4.500000
# C    2.500000
# dtype: float64

# %%
df
# Out:
#           A    B  C
# 0  1.000000  5.0  1
# 1  2.000000  NaN  2
# 2  2.333333  NaN  3
# 3  4.000000  4.0  4

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-2058252646.py in <cell line: 0>()
# ----> 1 df.groupby('Company').mean()
#
# NameError: name 'df' is not defined

# %%
df.mean(numeric_only=True)
# Out:
# A    2.333333
# B    4.500000
# C    2.500000
# dtype: float64

# %%
df.groupby('Company').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-4071839167.py in <cell line: 0>()
# ----> 1 df.groupby('Company').count()
#
# NameError: name 'df' is not defined
