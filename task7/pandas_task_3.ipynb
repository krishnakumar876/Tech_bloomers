# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp = df.groupby('Company')

# %%
byComp = df.groupby('Company')

# %%
df.dropna()
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df['Sales'].std()
# Out:
# 100.89945490437498

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1  13  19   3
# 2   8   7  14
# 3  14  10   5
# 4  16   4   5

# %%
df2
# Out:
#     W   X   Y
# 5  34  31  39
# 6  33  25  31
# 7  24  36  31
# 8  33  33  36

# %%
df3
# Out:
#      W   X   Y
# 9   56  52  42
# 10  54  51  42
# 11  49  54  53
# 12  50  45  41

# %%
farme = [df1,df2,df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1   13  19   3
# 2    8   7  14
# 3   14  10   5
# 4   16   4   5
# 5   34  31  39
# 6   33  25  31
# 7   24  36  31
# 8   33  33  36
# 9   56  52  42
# 10  54  51  42
# 11  49  54  53
# 12  50  45  41

# %%
pd.concat(farme, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1   13.0  19.0   3.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2    8.0   7.0  14.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   14.0  10.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   16.0   4.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  34.0  31.0  39.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  33.0  25.0  31.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  24.0  36.0  31.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  33.0  33.0  36.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  56.0  52.0  42.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  54.0  51.0  42.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  49.0  54.0  53.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  50.0  45.0  41.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[5,6,7,8]
}

# %%
left = pd.DataFrame(left)

# %%
right =pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C  D
# 0  k0  100  5
# 1  k1  200  6
# 2  k2  300  7
# 3  k3  400  8

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A  B    C  D
# 0  k0  10  1  100  5
# 1  k1  20  2  200  6
# 2  k2  30  3  300  7
# 3  k3  40  4  400  8

# %%
left ={
    'A':['A0','A1','A2','A3'],
    'B':['B0','B1','B2','B3']
}

# %%
right ={
    'C':['C0','C1','C2','C3'],
    'D':['D0','D1','D2','D3']
}

# %%
left = pd.DataFrame(left,index=['K0','K1','K2','K3'])

# %%
right = pd.DataFrame(right,index=['K0','K3','K4','K5'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
# K3  A3  B3

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K3  C1  D1
# K4  C2  D2
# K5  C3  D3

# %%
left.join(right,how = 'inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K3  A3  B3  C1  D1

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 4

# %%
df['col3'].value_counts()
# Out:
# col3
# abc    1
# def    1
# ghi    1
# xyz    1
# Name: count, dtype: int64

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
 df = pd.read_excel("/content/employee_data.xlsx")

# %%
df
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
df.head(10)
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
df.tail()
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 5                   7  Ahmedabad
# 6                   4       Pune
# 7                   8     Mumbai
# 8                   2  Hyderabad
# 9                  10     Jaipur

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Gender', 'Salary',
#        'JoinDate', 'Experience (Years)', 'Location'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['EmployeeID',
#  'Name',
#  'Department',
#  'Age',
#  'Gender',
#  'Salary',
#  'JoinDate',
#  'Experience (Years)',
#  'Location']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          10 non-null     int64
#  1   Name                10 non-null     object
#  2   Department          10 non-null     object
#  3   Age                 10 non-null     int64
#  4   Gender              10 non-null     object
#  5   Salary              10 non-null     int64
#  6   JoinDate            10 non-null     object
#  7   Experience (Years)  10 non-null     int64
#  8   Location            10 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes

# %%
df.nunique()
# Out:
# EmployeeID            10
# Name                  10
# Department             4
# Age                   10
# Gender                 2
# Salary                10
# JoinDate              10
# Experience (Years)     9
# Location               9
# dtype: int64

# %%
df
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
x = df
df.groupby('Location').count()
print(x)
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
bylocate = df.groupby('Location')

# %%
bylocate

# %%
df
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
df['Location']
# Out:
# 0      Chennai
# 1    Bangalore
# 2       Mumbai
# 3        Delhi
# 4        Kochi
# 5    Ahmedabad
# 6         Pune
# 7       Mumbai
# 8    Hyderabad
# 9       Jaipur
# Name: Location, dtype: object

# %%
df['Location'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Mumbai', 'Delhi', 'Kochi', 'Ahmedabad',
#        'Pune', 'Hyderabad', 'Jaipur'], dtype=object)

# %%
df['Location'].nunique()
# Out:
# 9

# %%
df
# Out:
#    EmployeeID         Name Department  Age  Gender  Salary    JoinDate  \
# 0         101   Ravi Kumar         HR   29    Male   45000  2018-03-01
# 1         102  Meena Singh         IT   32  Female   75000  2016-06-12
# 2         103  John Dsouza    Finance   28    Male   60000  2019-09-15
# 3         104   Anjali Roy         IT   24  Female   68000  2021-01-10
# 4         105   Rahul Nair  Marketing   35    Male   52000  2015-11-20
# 5         106   Sneha Shah         HR   30  Female   47000  2017-04-25
# 6         107  Akash Mehta         IT   27    Male   71000  2020-08-03
# 7         108   Priya Jain    Finance   31  Female   59000  2016-10-30
# 8         109    Arjun Rao  Marketing   26    Male   48000  2022-02-18
# 9         110   Neha Verma         HR   33  Female   50000  2014-05-07
#
#    Experience (Years)   Location
# 0                   6    Chennai
# 1                   8  Bangalore
# 2                   5     Mumbai
# 3                   3      Delhi
# ...

# %%
ex_years = df.groupby('Location')['Experience (Years)'].sum().reset_index()
ex_years
# Out:
#     Location  Experience (Years)
# 0  Ahmedabad                   7
# 1  Bangalore                   8
# 2    Chennai                   6
# 3      Delhi                   3
# 4  Hyderabad                   2
# 5     Jaipur                  10
# 6      Kochi                   9
# 7     Mumbai                  13
# 8       Pune                   4

# %%
ex_years_sorted=ex_years.sort_values('Experience (Years)',ascending=(True)).reset_index(drop=True)
ex_years_sorted
# Out:
#     Location  Experience (Years)
# 0  Hyderabad                   2
# 1      Delhi                   3
# 2       Pune                   4
# 3    Chennai                   6
# 4  Ahmedabad                   7
# 5  Bangalore                   8
# 6      Kochi                   9
# 7     Jaipur                  10
# 8     Mumbai                  13

# %%
ex_years_sorted=ex_years.sort_values('Experience (Years)',ascending=(False)).reset_index(drop=True)
ex_years_sorted
# Out:
#     Location  Experience (Years)
# 0     Mumbai                  13
# 1     Jaipur                  10
# 2      Kochi                   9
# 3  Bangalore                   8
# 4  Ahmedabad                   7
# 5    Chennai                   6
# 6       Pune                   4
# 7      Delhi                   3
# 8  Hyderabad                   2
